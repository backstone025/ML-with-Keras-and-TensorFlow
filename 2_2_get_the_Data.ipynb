# %% [markdown]
# <a href="https://colab.research.google.com/github/backstone025/ForTistory/blob/main/2_2_get_the_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# %% [markdown]
# #Download the Data
#
# ##작동:
# 1. 해당 파일이 있는가?
# 그렇다 -> 값으로 해당 파일을 return한다.
# 2. 아니다 -> url주소에 있는 경로를 찾아서 해당 파일을 Download하고 해당 파일을 return 한다.
#
# - pathlib
# https://docs.python.org/ko/3/library/pathlib.html
#
# pathlib는 서로 다른 운영체제 간에 파일 시스템 경로를 나타내는 class(객체)를 return하는 module이다.
#
#
# ```
# tarball_path = Path("datasets/housing.tgz")
# ```
# 이 코드에서 datasets/housing.tgz의 경로를 객체로 tarball_path에 저장함을 알 수 있다.
#
#
# ```
# if not tarball_path.is_file():
# ```
# method : is_file
#
# 이 부분에서 datasets/housing.tgz를 가리키고 있는지 나타낸다.
#
# 만일 가리키고 있지 않으면 False를 return한다.(해당 파일이 없으면 False를 return한다.)
#
#
#
#
# ```
# Path("datasets").mkdir(parents=True, exist_ok=True)
# ```
#
# method: mkdir
# 이 부분은 기존에 주어진 경로에 대한 새 directory(window: 폴더)를 만드는 부분이다.
#
# parent : 해당 경로의 parent가 없어도 필요에 따라 생성여부
#
# 만일 False면 경로의 parent가 없으면 error를 일으키고 종료
#
# exist_ok : 만일 directory가 이미 있으면 무시할지 여부
#
#
# - urllib.request https://docs.python.org/3/library/urllib.request.html?highlight=request#module-urllib.request
#
# url 관련 라이브러리이다.
#
# urllib.request는 url을 여는데 도움을 주는 라이브러리이다.
#
#
# ```
# urllib.request.urlretrieve(url, tarball_path)
# ```
#
# 이 부분은 주어진 url에서 파일을 다운로드하여 로컬파일시스템에 저장하는 부분이다.
#
# url주소와 로컬로 저장할 파일 경로와 이름을 매개변수로 가진다.
#
# 여기서 파일경로와 이름은 문자열 형식, 또는 pathlib.path를 사용해야 한다.
#
# - with 문
#
# with 문은 하나의 사이클을 간단하게 작성하는데 도움을 준다.
#
# 여기서 파일을 열고 닫는데 사용되었다.
#
#
# ```
# with tarfile.open(tarball_path) as housing_tarball:
# ```
#
# 이 코드에서 with 문은 일종의 줄인 표현이다.
#
#
# ```
# housing_tarball = tarfile.open(tarball_path)
#
# ...
#
# housing_tarball.close
# ```
#
# with 구문을 사용하면 자동으로 열고 닫음을 관리해주기에 크게 신경 쓸 필요 없다.
#
#
# - tarfile https://docs.python.org/3/library/tarfile.html?highlight=tarfile%20open#tarfile.open
#
# tarfile은 TAR형식의 아키텍처파일을 다루는데 사용된다.
#
#
#
# ```
# housing_tarball.extractall(path="datasets")
# ```
# - extractall https://docs.python.org/3/library/tarfile.html?highlight=extractall#tarfile.TarFile.extractall
#
# extractall은 해당 경로의 directory의 내용을 추출하는데 사용된다.
#
#
#
# ```
# return pd.read_csv(Path("datasets/housing/housing.csv"))
# ```
#
# - pandas https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# pandas는 데이터와 관련한 조작, 분석을 위해 파이썬으로 구현된 라이브러리이다.
# 여기서 A comma-separated values (csv) file is returned as two-dimensional data structure with labeled axes.라고 설명하는데,
# dataframe을 설명하는 용어로 이는 리스트나 배열과는 다른 구조이다.
#
#
# ##사용이유:
# 직접 입력하면 최신 data들을 fetch하는데, 불편함이 있기에 편리하게 사용하기 위해 이 방법을 써야 함.
